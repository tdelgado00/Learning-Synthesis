# %%
import pandas as pd
import pdb
path_components_by_state_1 = "/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_5_over_boolean/100_subset_5000_budget.csv"
paths = [f"/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean/boolean_{k}/DP/upTo:15_timeout2h_ebudget5000_generalization_all.csv" for k in range(1,6)]
paths.append(path_components_by_state_1)
path_boolean_2_k = "/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_5_over_boolean/100_subset_5000_budget.csv"
paths.append(path_boolean_2_k)
paths.append("/home/marco/Desktop/Learning-Synthesis/experiments/results/RA/DP/all_ra_15000t.csv")
def most_solved_instances_untie_by_least_transitions_fixed_level(df, level):
    """Selects the agent that solves the most instances, and in case of a tie, untie by #transitions"""
    df = df[(df["expansion_budget_exceeded"]==False) & (df["k"]==level)]
    if df.shape[0]==0: return None
    return df.sort_values(["n","expanded transitions"], ascending = [False,True]).head(1).iloc[0][["n", "k", "expanded transitions", "used transitions", "heuristic"]]
def compare_most_solved_instances_untie_by_least_transitions_fixed_level(dfs, level):
    final_result = pd.DataFrame()
    heuristics = []
    
    for df in dfs:
        res = most_solved_instances_untie_by_least_transitions_fixed_level(df, level)
        if res is None: continue
        final_result = pd.concat([final_result,res], axis=1)
        heuristics.append(res["heuristic"])
        
    final_result.columns = heuristics
    return final_result

# %%
res = compare_most_solved_instances_untie_by_least_transitions_fixed_level([pd.read_csv(path) for path in paths], 1)

# %%
res
# Out:
#                       experiments/results/DP_2_2/boolean/68.onnx  \
# n                                                              6
# k                                                              1
# expanded transitions                                        1674
# used transitions                                             448
# heuristic             experiments/results/DP_2_2/boolean/68.onnx
#
#                       experiments/results/DP_2_2/boolean_2/53.onnx  \
# n                                                                6
# k                                                                1
# expanded transitions                                          4455
# used transitions                                               253
# heuristic             experiments/results/DP_2_2/boolean_2/53.onnx
#
#                       experiments/results/DP_2_2/boolean_3/69.onnx  \
# n                                                                6
# k                                                                1
# expanded transitions                                          3504
# used transitions                                               485
# heuristic             experiments/results/DP_2_2/boolean_3/69.onnx
#
#                       experiments/results/DP_2_2/boolean_4/55.onnx  \
# n                                                                7
# k                                                                1
# expanded transitions                                          3617
# used transitions                                               524
# heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                       experiments/results/DP_2_2/boolean_5/50.onnx      r
# n                                                                7     11
# k                                                                1      1
# expanded transitions                                          4866  11995
# used transitions                                               511  11350
# heuristic             experiments/results/DP_2_2/boolean_5/50.onnx      r

# %%
path_components_by_state_3 = "/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_5_over_boolean/100_subset_5000_budget.csv"
paths = [f"/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean/boolean_{k}/DP/upTo:15_timeout2h_ebudget5000_generalization_all.csv" for k in range(1,6)]
paths.append(path_components_by_state_3)
path_boolean_3_k = "/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_5_over_boolean/100_subset_5000_budget.csv"
paths.append(path_boolean_3_k)
paths.append("/home/marco/Desktop/Learning-Synthesis/experiments/results/RA/DP/all_ra_15000t.csv")

# %%
res = compare_most_solved_instances_untie_by_least_transitions_fixed_level([pd.read_csv(path) for path in paths], 3)

# %%
res

# %%
path_components_by_state_5 = "/home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_3_k_over_boolean/components_by_state_DP_3_5_over_boolean/100_subset_5000_budget.csv"
paths = [f"/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean/boolean_{k}/DP/upTo:15_timeout2h_ebudget5000_generalization_all.csv" for k in range(1,6)]
paths.append(path_components_by_state_5)
path_boolean_3_k = "/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_3_k/boolean_DP_3_5_over_boolean/100_subset_5000_budget.csv"
paths.append(path_boolean_3_k)
paths.append("/home/marco/Desktop/Learning-Synthesis/experiments/results/RA/DP/all_ra_15000t.csv")

res = compare_most_solved_instances_untie_by_least_transitions_fixed_level([pd.read_csv(path) for path in paths], 5)
res
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-02f6b7e10d8c> in <module>
#       6 paths.append("/home/marco/Desktop/Learning-Synthesis/experiments/results/RA/DP/all_ra_15000t.csv")
#       7
# ----> 8 res = compare_most_solved_instances_untie_by_least_transitions_fixed_level([pd.read_csv(path) for path in paths], 5)
#       9 res
#
# <ipython-input-24-02f6b7e10d8c> in <listcomp>(.0)
#       6 paths.append("/home/marco/Desktop/Learning-Synthesis/experiments/results/RA/DP/all_ra_15000t.csv")
#       7
# ----> 8 res = compare_most_solved_instances_untie_by_least_transitions_fixed_level([pd.read_csv(path) for path in paths], 5)
#       9 res
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_3_k_over_boolean/components_by_state_DP_3_7_over_boolean/100_subset_5000_budget.csv'

# %%
def analysis(level):
    path_components_by_state_3 = f"/home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean/components_by_state_DP_2_{level}_over_boolean/100_subset_5000_budget.csv"
    paths = [f"/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean/boolean_{k}/DP/upTo:15_timeout2h_ebudget5000_generalization_all.csv" for k in range(1,6)]
    paths.append(path_components_by_state_3)
    path_boolean_3_k = f"/home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_{level}_over_boolean/100_subset_5000_budget.csv"
    paths.append(path_boolean_3_k)
    paths.append("/home/marco/Desktop/Learning-Synthesis/experiments/results/RA/DP/all_ra_15000t.csv")
    res = compare_most_solved_instances_untie_by_least_transitions_fixed_level([pd.read_csv(path) for path in paths], level)
    return res

# %%
[analysis(k) for k in range(1,16)]
# Out:
# [                      experiments/results/DP_2_2/boolean/68.onnx  \
#  n                                                              6
#  k                                                              1
#  expanded transitions                                        1674
#  used transitions                                             448
#  heuristic             experiments/results/DP_2_2/boolean/68.onnx
#
#                        experiments/results/DP_2_2/boolean_2/53.onnx  \
#  n                                                                6
#  k                                                                1
#  expanded transitions                                          4455
#  used transitions                                               253
#  heuristic             experiments/results/DP_2_2/boolean_2/53.onnx
#
#                        experiments/results/DP_2_2/boolean_3/69.onnx  \
#  n                                                                6
#  k                                                                1
#  expanded transitions                                          3504
#  used transitions                                               485
#  heuristic             experiments/results/DP_2_2/boolean_3/69.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                7
#  k                                                                1
#  expanded transitions                                          3617
#  used transitions                                               524
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                7
#  k                                                                1
#  expanded transitions                                          4866
#  used transitions                                               511
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_1_over_boolean/  \
#  n                                                                     6
#  k                                                                     1
#  expanded transitions                                               2203
#  used transitions                                                    243
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_1_over_boolean/  \
#  n                                                                     6
#  k                                                                     1
#  expanded transitions                                               2186
#  used transitions                                                    466
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                        11
#  k                         1
#  expanded transitions  11995
#  used transitions      11350
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/51.onnx  \
#  n                                                              5
#  k                                                              2
#  expanded transitions                                         858
#  used transitions                                             145
#  heuristic             experiments/results/DP_2_2/boolean/51.onnx
#
#                        experiments/results/DP_2_2/boolean_2/3.onnx  \
#  n                                                               5
#  k                                                               2
#  expanded transitions                                         2377
#  used transitions                                              147
#  heuristic             experiments/results/DP_2_2/boolean_2/3.onnx
#
#                        experiments/results/DP_2_2/boolean_3/53.onnx  \
#  n                                                                5
#  k                                                                2
#  expanded transitions                                          1786
#  used transitions                                               572
#  heuristic             experiments/results/DP_2_2/boolean_3/53.onnx
#
#                        experiments/results/DP_2_2/boolean_4/52.onnx  \
#  n                                                                6
#  k                                                                2
#  expanded transitions                                          3824
#  used transitions                                               336
#  heuristic             experiments/results/DP_2_2/boolean_4/52.onnx
#
#                        experiments/results/DP_2_2/boolean_5/61.onnx  \
#  n                                                                6
#  k                                                                2
#  expanded transitions                                          3331
#  used transitions                                               711
#  heuristic             experiments/results/DP_2_2/boolean_5/61.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_2_over_boolean//58.onnx  \
#  n                                                                     6
#  k                                                                     2
#  expanded transitions                                               2521
#  used transitions                                                    249
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_2_over_boolean//31.onnx  \
#  n                                                                     5
#  k                                                                     2
#  expanded transitions                                               2191
#  used transitions                                                    139
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                        11
#  k                         2
#  expanded transitions  11811
#  used transitions      11421
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/55.onnx  \
#  n                                                              5
#  k                                                              3
#  expanded transitions                                         539
#  used transitions                                             134
#  heuristic             experiments/results/DP_2_2/boolean/55.onnx
#
#                        experiments/results/DP_2_2/boolean_2/68.onnx  \
#  n                                                                5
#  k                                                                3
#  expanded transitions                                          2990
#  used transitions                                               134
#  heuristic             experiments/results/DP_2_2/boolean_2/68.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                3
#  expanded transitions                                          1671
#  used transitions                                               150
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/76.onnx  \
#  n                                                                5
#  k                                                                3
#  expanded transitions                                           765
#  used transitions                                               237
#  heuristic             experiments/results/DP_2_2/boolean_4/76.onnx
#
#                        experiments/results/DP_2_2/boolean_5/51.onnx  \
#  n                                                                6
#  k                                                                3
#  expanded transitions                                          3856
#  used transitions                                               699
#  heuristic             experiments/results/DP_2_2/boolean_5/51.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_3_over_boolean/  \
#  n                                                                     7
#  k                                                                     3
#  expanded transitions                                               4900
#  used transitions                                                    520
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_3_over_boolean/  \
#  n                                                                     6
#  k                                                                     3
#  expanded transitions                                               1505
#  used transitions                                                    524
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                        11
#  k                         3
#  expanded transitions  12199
#  used transitions      11552
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                              4
#  expanded transitions                                        2203
#  used transitions                                             290
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/3.onnx  \
#  n                                                               5
#  k                                                               4
#  expanded transitions                                         2982
#  used transitions                                              149
#  heuristic             experiments/results/DP_2_2/boolean_2/3.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                4
#  expanded transitions                                          1930
#  used transitions                                               169
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/52.onnx  \
#  n                                                                5
#  k                                                                4
#  expanded transitions                                          1517
#  used transitions                                               192
#  heuristic             experiments/results/DP_2_2/boolean_4/52.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                                4
#  expanded transitions                                          1943
#  used transitions                                               145
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_4_over_boolean//43.onnx  \
#  n                                                                     5
#  k                                                                     4
#  expanded transitions                                               1866
#  used transitions                                                    139
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_4_over_boolean//54.onnx  \
#  n                                                                     5
#  k                                                                     4
#  expanded transitions                                               3130
#  used transitions                                                    149
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                        11
#  k                         4
#  expanded transitions  12307
#  used transitions      11563
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                              5
#  expanded transitions                                        2461
#  used transitions                                             315
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/3.onnx  \
#  n                                                               5
#  k                                                               5
#  expanded transitions                                         3465
#  used transitions                                              438
#  heuristic             experiments/results/DP_2_2/boolean_2/3.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                5
#  expanded transitions                                          2188
#  used transitions                                               173
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/52.onnx  \
#  n                                                                5
#  k                                                                5
#  expanded transitions                                          1723
#  used transitions                                               201
#  heuristic             experiments/results/DP_2_2/boolean_4/52.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                                5
#  expanded transitions                                          1126
#  used transitions                                               155
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_5_over_boolean/  \
#  n                                                                     6
#  k                                                                     5
#  expanded transitions                                               3507
#  used transitions                                                    310
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_5_over_boolean/  \
#  n                                                                     5
#  k                                                                     5
#  expanded transitions                                               2368
#  used transitions                                                    144
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                        10
#  k                         5
#  expanded transitions  13763
#  used transitions       5799
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                              6
#  expanded transitions                                        2723
#  used transitions                                             340
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/3.onnx  \
#  n                                                               5
#  k                                                               6
#  expanded transitions                                         4449
#  used transitions                                              163
#  heuristic             experiments/results/DP_2_2/boolean_2/3.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                6
#  expanded transitions                                          2447
#  used transitions                                               189
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/52.onnx  \
#  n                                                                5
#  k                                                                6
#  expanded transitions                                          1929
#  used transitions                                               210
#  heuristic             experiments/results/DP_2_2/boolean_4/52.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                                6
#  expanded transitions                                          1600
#  used transitions                                               161
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_6_over_boolean//50.onnx  \
#  n                                                                     7
#  k                                                                     6
#  expanded transitions                                               3566
#  used transitions                                                    541
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_6_over_boolean//73.onnx  \
#  n                                                                     4
#  k                                                                     6
#  expanded transitions                                                758
#  used transitions                                                     89
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                         9
#  k                         6
#  expanded transitions  12249
#  used transitions       3041
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                              7
#  expanded transitions                                        2981
#  used transitions                                             365
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/3.onnx  \
#  n                                                               5
#  k                                                               7
#  expanded transitions                                         4916
#  used transitions                                              417
#  heuristic             experiments/results/DP_2_2/boolean_2/3.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                7
#  expanded transitions                                          2706
#  used transitions                                               199
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                                7
#  expanded transitions                                          2072
#  used transitions                                               185
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                                7
#  expanded transitions                                          3876
#  used transitions                                               154
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_7_over_boolean/  \
#  n                                                                     6
#  k                                                                     7
#  expanded transitions                                               4075
#  used transitions                                                    279
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_7_over_boolean/  \
#  n                                                                     5
#  k                                                                     7
#  expanded transitions                                               4277
#  used transitions                                                    353
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                            r
#  n                         9
#  k                         7
#  expanded transitions  14665
#  used transitions       3050
#  heuristic                 r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                              8
#  expanded transitions                                        3243
#  used transitions                                             421
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/55.onnx  \
#  n                                                                4
#  k                                                                8
#  expanded transitions                                           601
#  used transitions                                                97
#  heuristic             experiments/results/DP_2_2/boolean_2/55.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                8
#  expanded transitions                                          2965
#  used transitions                                               200
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                                8
#  expanded transitions                                          2280
#  used transitions                                               194
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                                8
#  expanded transitions                                          4605
#  used transitions                                               159
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_8_over_boolean//52.onnx  \
#  n                                                                     5
#  k                                                                     8
#  expanded transitions                                               2470
#  used transitions                                                    159
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_8_over_boolean//58.onnx  \
#  n                                                                     4
#  k                                                                     8
#  expanded transitions                                               3806
#  used transitions                                                    107
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        6
#  k                        8
#  expanded transitions  7472
#  used transitions      1205
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                              9
#  expanded transitions                                        3501
#  used transitions                                             447
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/54.onnx  \
#  n                                                                4
#  k                                                                9
#  expanded transitions                                          1009
#  used transitions                                               101
#  heuristic             experiments/results/DP_2_2/boolean_2/54.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                                9
#  expanded transitions                                          3224
#  used transitions                                               185
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                                9
#  expanded transitions                                          2489
#  used transitions                                               183
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                                9
#  expanded transitions                                          1531
#  used transitions                                               179
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_9_over_boolean/  \
#  n                                                                     5
#  k                                                                     9
#  expanded transitions                                               2051
#  used transitions                                                    193
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_9_over_boolean/  \
#  n                                                                     5
#  k                                                                     9
#  expanded transitions                                               3900
#  used transitions                                                    368
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        6
#  k                        9
#  expanded transitions  8313
#  used transitions      1211
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                             10
#  expanded transitions                                        3763
#  used transitions                                             440
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/55.onnx  \
#  n                                                                4
#  k                                                               10
#  expanded transitions                                           682
#  used transitions                                               121
#  heuristic             experiments/results/DP_2_2/boolean_2/55.onnx
#
#                        experiments/results/DP_2_2/boolean_3/20.onnx  \
#  n                                                                5
#  k                                                               10
#  expanded transitions                                          3483
#  used transitions                                               229
#  heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                               10
#  expanded transitions                                          2698
#  used transitions                                               169
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                               10
#  expanded transitions                                          2936
#  used transitions                                               185
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_10_over_boolean//80.onnx  \
#  n                                                                     6
#  k                                                                    10
#  expanded transitions                                               3313
#  used transitions                                                    297
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_10_over_boolean//118.onnx  \
#  n                                                                     6
#  k                                                                    10
#  expanded transitions                                               4746
#  used transitions                                                    297
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        5
#  k                       10
#  expanded transitions  3062
#  used transitions       689
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/71.onnx  \
#  n                                                              5
#  k                                                             11
#  expanded transitions                                        4021
#  used transitions                                             465
#  heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                        experiments/results/DP_2_2/boolean_2/55.onnx  \
#  n                                                                4
#  k                                                               11
#  expanded transitions                                          1261
#  used transitions                                               137
#  heuristic             experiments/results/DP_2_2/boolean_2/55.onnx
#
#                        experiments/results/DP_2_2/boolean_3/51.onnx  \
#  n                                                                4
#  k                                                               11
#  expanded transitions                                          1823
#  used transitions                                               134
#  heuristic             experiments/results/DP_2_2/boolean_3/51.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                               11
#  expanded transitions                                          2907
#  used transitions                                               221
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                               11
#  expanded transitions                                          4103
#  used transitions                                               187
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_11_over_boolean/  \
#  n                                                                     5
#  k                                                                    11
#  expanded transitions                                               3125
#  used transitions                                                    174
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_11_over_boolean/  \
#  n                                                                     5
#  k                                                                    11
#  expanded transitions                                               3423
#  used transitions                                                    393
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        5
#  k                       11
#  expanded transitions  3345
#  used transitions       694
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/59.onnx  \
#  n                                                              4
#  k                                                             12
#  expanded transitions                                        2822
#  used transitions                                             113
#  heuristic             experiments/results/DP_2_2/boolean/59.onnx
#
#                        experiments/results/DP_2_2/boolean_2/54.onnx  \
#  n                                                                4
#  k                                                               12
#  expanded transitions                                          1360
#  used transitions                                               113
#  heuristic             experiments/results/DP_2_2/boolean_2/54.onnx
#
#                        experiments/results/DP_2_2/boolean_3/51.onnx  \
#  n                                                                4
#  k                                                               12
#  expanded transitions                                          1967
#  used transitions                                               140
#  heuristic             experiments/results/DP_2_2/boolean_3/51.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                               12
#  expanded transitions                                          3117
#  used transitions                                               230
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                               12
#  expanded transitions                                          1748
#  used transitions                                               197
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_12_over_boolean//59.onnx  \
#  n                                                                     5
#  k                                                                    12
#  expanded transitions                                               2976
#  used transitions                                                    232
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_12_over_boolean//93.onnx  \
#  n                                                                     4
#  k                                                                    12
#  expanded transitions                                               2267
#  used transitions                                                    113
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        5
#  k                       12
#  expanded transitions  3644
#  used transitions       699
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/51.onnx  \
#  n                                                              4
#  k                                                             13
#  expanded transitions                                        2001
#  used transitions                                             172
#  heuristic             experiments/results/DP_2_2/boolean/51.onnx
#
#                        experiments/results/DP_2_2/boolean_2/54.onnx  \
#  n                                                                4
#  k                                                               13
#  expanded transitions                                          1375
#  used transitions                                               132
#  heuristic             experiments/results/DP_2_2/boolean_2/54.onnx
#
#                        experiments/results/DP_2_2/boolean_3/51.onnx  \
#  n                                                                4
#  k                                                               13
#  expanded transitions                                          2111
#  used transitions                                               146
#  heuristic             experiments/results/DP_2_2/boolean_3/51.onnx
#
#                        experiments/results/DP_2_2/boolean_4/52.onnx  \
#  n                                                                5
#  k                                                               13
#  expanded transitions                                          3371
#  used transitions                                               273
#  heuristic             experiments/results/DP_2_2/boolean_4/52.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                               13
#  expanded transitions                                          3665
#  used transitions                                               213
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_13_over_boolean/  \
#  n                                                                     5
#  k                                                                    13
#  expanded transitions                                               3132
#  used transitions                                                    259
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_13_over_boolean/  \
#  n                                                                     4
#  k                                                                    13
#  expanded transitions                                               1470
#  used transitions                                                    144
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        5
#  k                       13
#  expanded transitions  3959
#  used transitions       704
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/59.onnx  \
#  n                                                              4
#  k                                                             14
#  expanded transitions                                        3186
#  used transitions                                             121
#  heuristic             experiments/results/DP_2_2/boolean/59.onnx
#
#                        experiments/results/DP_2_2/boolean_2/54.onnx  \
#  n                                                                4
#  k                                                               14
#  expanded transitions                                          1438
#  used transitions                                               137
#  heuristic             experiments/results/DP_2_2/boolean_2/54.onnx
#
#                        experiments/results/DP_2_2/boolean_3/51.onnx  \
#  n                                                                4
#  k                                                               14
#  expanded transitions                                          2255
#  used transitions                                               152
#  heuristic             experiments/results/DP_2_2/boolean_3/51.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                               14
#  expanded transitions                                          3534
#  used transitions                                               189
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                               14
#  expanded transitions                                          3101
#  used transitions                                               209
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/components_by_state_DP_2_k_over_boolean//components_by_state_DP_2_14_over_boolean//71.onnx  \
#  n                                                                     5
#  k                                                                    14
#  expanded transitions                                               3325
#  used transitions                                                    268
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean//boolean_DP_2_14_over_boolean//74.onnx  \
#  n                                                                     4
#  k                                                                    14
#  expanded transitions                                               4967
#  used transitions                                                    176
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        5
#  k                       14
#  expanded transitions  4290
#  used transitions       709
#  heuristic                r  ,
#                        experiments/results/DP_2_2/boolean/51.onnx  \
#  n                                                              4
#  k                                                             15
#  expanded transitions                                        2249
#  used transitions                                             209
#  heuristic             experiments/results/DP_2_2/boolean/51.onnx
#
#                        experiments/results/DP_2_2/boolean_2/54.onnx  \
#  n                                                                4
#  k                                                               15
#  expanded transitions                                          1501
#  used transitions                                               142
#  heuristic             experiments/results/DP_2_2/boolean_2/54.onnx
#
#                        experiments/results/DP_2_2/boolean_3/51.onnx  \
#  n                                                                4
#  k                                                               15
#  expanded transitions                                          2399
#  used transitions                                               158
#  heuristic             experiments/results/DP_2_2/boolean_3/51.onnx
#
#                        experiments/results/DP_2_2/boolean_4/55.onnx  \
#  n                                                                5
#  k                                                               15
#  expanded transitions                                          3743
#  used transitions                                               257
#  heuristic             experiments/results/DP_2_2/boolean_4/55.onnx
#
#                        experiments/results/DP_2_2/boolean_5/50.onnx  \
#  n                                                                5
#  k                                                               15
#  expanded transitions                                          1851
#  used transitions                                               290
#  heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_15_over_boolean/  \
#  n                                                                     5
#  k                                                                    15
#  expanded transitions                                               3428
#  used transitions                                                    277
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                       /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_15_over_boolean/  \
#  n                                                                     4
#  k                                                                    15
#  expanded transitions                                               3883
#  used transitions                                                    125
#  heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
#  n                        5
#  k                       15
#  expanded transitions  4637
#  used transitions       714
#  heuristic                r  ]

# %%
analysis(3)
# Out:
#                       experiments/results/DP_2_2/boolean/55.onnx  \
# n                                                              5
# k                                                              3
# expanded transitions                                         539
# used transitions                                             134
# heuristic             experiments/results/DP_2_2/boolean/55.onnx
#
#                       experiments/results/DP_2_2/boolean_2/68.onnx  \
# n                                                                5
# k                                                                3
# expanded transitions                                          2990
# used transitions                                               134
# heuristic             experiments/results/DP_2_2/boolean_2/68.onnx
#
#                       experiments/results/DP_2_2/boolean_3/20.onnx  \
# n                                                                5
# k                                                                3
# expanded transitions                                          1671
# used transitions                                               150
# heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                       experiments/results/DP_2_2/boolean_4/76.onnx  \
# n                                                                5
# k                                                                3
# expanded transitions                                           765
# used transitions                                               237
# heuristic             experiments/results/DP_2_2/boolean_4/76.onnx
#
#                       experiments/results/DP_2_2/boolean_5/51.onnx  \
# n                                                                6
# k                                                                3
# expanded transitions                                          3856
# used transitions                                               699
# heuristic             experiments/results/DP_2_2/boolean_5/51.onnx
#
#                      /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_3_over_boolean/  \
# n                                                                     7
# k                                                                     3
# expanded transitions                                               4900
# used transitions                                                    520
# heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                      /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_3_over_boolean/  \
# n                                                                     6
# k                                                                     3
# expanded transitions                                               1505
# used transitions                                                    524
# heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
# n                        11
# k                         3
# expanded transitions  12199
# used transitions      11552
# heuristic                 r

# %%
# Out:
#                       experiments/results/DP_2_2/boolean/71.onnx  \
# n                                                              5
# k                                                              5
# expanded transitions                                        2461
# used transitions                                             315
# heuristic             experiments/results/DP_2_2/boolean/71.onnx
#
#                       experiments/results/DP_2_2/boolean_2/3.onnx  \
# n                                                               5
# k                                                               5
# expanded transitions                                         3465
# used transitions                                              438
# heuristic             experiments/results/DP_2_2/boolean_2/3.onnx
#
#                       experiments/results/DP_2_2/boolean_3/20.onnx  \
# n                                                                5
# k                                                                5
# expanded transitions                                          2188
# used transitions                                               173
# heuristic             experiments/results/DP_2_2/boolean_3/20.onnx
#
#                       experiments/results/DP_2_2/boolean_4/52.onnx  \
# n                                                                5
# k                                                                5
# expanded transitions                                          1723
# used transitions                                               201
# heuristic             experiments/results/DP_2_2/boolean_4/52.onnx
#
#                       experiments/results/DP_2_2/boolean_5/50.onnx  \
# n                                                                5
# k                                                                5
# expanded transitions                                          1126
# used transitions                                               155
# heuristic             experiments/results/DP_2_2/boolean_5/50.onnx
#
#                      /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/components_by_state_DP_2_5_over_boolean/  \
# n                                                                     6
# k                                                                     5
# expanded transitions                                               3507
# used transitions                                                    310
# heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                      /home/marco/Desktop/Learning-Synthesis/experiments/results/boolean_DP_2_k_over_boolean/boolean_DP_2_5_over_boolean/  \
# n                                                                     5
# k                                                                     5
# expanded transitions                                               2368
# used transitions                                                    144
# heuristic             /home/marco/Desktop/Learning-Synthesis/experim...
#
#                           r
# n                        10
# k                         5
# expanded transitions  13763
# used transitions       5799
# heuristic                 r
